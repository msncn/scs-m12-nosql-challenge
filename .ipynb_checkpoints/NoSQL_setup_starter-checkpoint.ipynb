# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
print(db.establishments.find_one())
# Out:
# {'_id': ObjectId('64bdac304823ed3bc60a6f2f'), 'FHRSID': 254719, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000069980', 'BusinessName': 'Refreshment Kiosk', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'The Bay', 'AddressLine2': 'St Margarets Bay', 'AddressLine3': 'Kent', 'AddressLine4': '', 'PostCode': 'CT15 6DY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-03-24T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Dover', 'LocalAuthorityWebSite': 'http://www.dover.gov.uk/', 'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.387974', 'latitude': '51.152225'}, 'RightToReply': '', 'Distance': 4587.347174863443, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one(new_restaurant))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bdd2555590f3dc6ad008e3'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields

query = {'BusinessType':'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID':1, 'BusinessTpye':1}

results = list(establishments.find(query, fields))

pprint(results)
# Out:
# [{'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f2f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f30')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f32')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f3e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f43')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f44')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f45')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f47')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f48')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f49')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f4d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f4f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f52')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f53')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f54')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f5f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f61')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f62')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f64')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f66')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f69')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f6d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f6e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f70')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f71')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f72')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f73')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f76')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f7a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f7c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f7e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f89')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f8b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f8c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f90')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f92')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f93')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f94')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6f99')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fa2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fa5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fa6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fa7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6faa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fae')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6faf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fb0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fb2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fb3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fb9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fbb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fbc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fc4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fca')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fcd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fd0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fd1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fd3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fd4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fd7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fdb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fdc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fde')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fe4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fe8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fe9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6fef')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6ff3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a6ffd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7001')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7006')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7008')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a700e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a701b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a701d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a701e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7020')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7022')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a702d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7037')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a703c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a703e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7041')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7042')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7047')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a704e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a704f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7050')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a705b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a705c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7063')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7068')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7069')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a706a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a706c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7072')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7075')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7076')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7078')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7079')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a707c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a707d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a707e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7081')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7082')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7083')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7084')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7086')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a708c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7095')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7096')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7097')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7098')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a709b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a709e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70a1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70a2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70a6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70a7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70a8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70c0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70c1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70c2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70c4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70c8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70c9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70cb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70d0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70d1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70d8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70da')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70dc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70e0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70e3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70e4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70e7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70ea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70f1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70f6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a70fa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7106')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7112')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a713b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a713d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7143')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7145')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a714a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a714b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a715a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a715c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a716a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a718a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a718e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7197')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71a1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71a2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71a6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71a7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71b9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71bf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71c6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71ca')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71d5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71d6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71dc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71e2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71e3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71e4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71e7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71ef')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71fa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a71fb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7201')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7206')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a720a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7216')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a721a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a721e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a721f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7227')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a722e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7234')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7237')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a723c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a723e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a723f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7243')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7258')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a725d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7261')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7262')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7264')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7267')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a726a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a726c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a726d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a726f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7270')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7276')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7278')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7279')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a727c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7282')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7284')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7287')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7289')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a728e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a728f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7290')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a729c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a729d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a729e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72a3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72a4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72a7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72a8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72aa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72b0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72b1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72b4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72b5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72bc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72bf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72c3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72c5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72cc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72cd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72ce')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72d6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72d8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72df')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72e4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72e6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72e8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72ea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72f2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72f3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72f6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72f7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72fb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72fe')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a72ff')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7300')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7301')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7307')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7309')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a730b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a730e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a730f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7312')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7317')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7318')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7319')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a731b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7320')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7321')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7323')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7324')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a732c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7332')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7333')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7336')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a733a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a733d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7342')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a734d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a734e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7364')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7368')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7369')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a736d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7371')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a737e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7380')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a738c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7393')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7395')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a7399')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73a2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73a3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73a4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73a6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73a7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73a8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73aa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73ac')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73b0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73b2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73b3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73b4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73b7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73bd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73bf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73c0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73c2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73c3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73c4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73c6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73c7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73c8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73c9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73ca')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73cb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73ce')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73dd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73e0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73e2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73ea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73eb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a73ed')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a
},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac304823ed3bc60a791b')},
# ...
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0767')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0768')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0769')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b076c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0773')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0777')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0779')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0780')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0787')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0789')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b078b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b078c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0799')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b079d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b079e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b079f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07a0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07a1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07a3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07a4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07ac')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07b2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07b9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07bc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07c2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07c7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07cd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07ce')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07d0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07d3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07d4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07d5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07d7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07d8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07d9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07df')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07eb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07ef')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07f0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07f1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07f5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07f7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07fb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07fd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b07fe')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0800')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0801')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0802')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0804')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0805')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b080b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b080e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b080f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0812')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0816')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0817')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b081e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b081f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0820')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0823')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0824')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0826')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b082d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b082e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0831')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0835')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b083c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0845')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0846')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b084b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b084d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b084f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0853')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0855')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b085e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b085f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0863')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0864')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0866')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b086b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b086e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b086f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0874')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0875')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0877')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0879')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b087c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b087d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b087e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b087f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0881')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0883')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0886')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0889')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b088b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b088f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0890')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0891')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b089c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b089f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08a0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08a5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08a6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08a7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08a9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08aa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08ab')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08ac')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08ad')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08b3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08b4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08b6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08b8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08b9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08bd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08bf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08c1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08c5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08c6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08cb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08cc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08ce')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08d3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08d4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08d6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08dd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08e2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08e4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08e8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08ee')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08f1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08f5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08fb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b08fe')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0905')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0926')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b092c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b092d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0935')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0936')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0939')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b093a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b093d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b093f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0940')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0941')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0942')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0943')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0953')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b095d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0964')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0965')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0969')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b096e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0974')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0976')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0979')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b097e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0984')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0985')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0986')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0987')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b099a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b099c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09a8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09ad')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09ae')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09b6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09c0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09c3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09c7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09cb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09cf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09d3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09d5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09e1')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09e2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09e3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09e6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09e7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09e9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09ea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09ed')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09ee')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09f0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09f2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09f6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09f8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09f9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09fb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09fc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b09ff')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a00')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a03')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a04')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a05')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a0a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a0e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a11')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a12')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a14')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a18')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a19')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a1d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a20')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a25')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a31')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a36')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a38')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a39')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a3e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a3f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a4f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a52')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a57')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a5c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a62')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a70')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a72')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a75')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a7f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a80')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a83')},
#  {'BusinessTypeID': 1, '_id': ObjectId('64bdac314823ed3bc60b0a91')},
#  {'BusinessTypeID': '', '_id': ObjectId('64bdd2555590f3dc6ad008e3')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_many(
    {'BusinessType': 'Restaurant/Cafe/Canteen'},
    {'$set':
        {'BusinessTypeID': 1}
     }
)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': "Penang Flavours"}

results = list(establishments.find(query))

pprint(results)
# Out:
# [{'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'Distance': 4623.972328074718,
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64bdd2555590f3dc6ad008e3'),
#   'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_query = {'$match': {'LocalAuthorityName': "Dover"}}

dover = [dover_query]

results = list(establishments.aggregate(dover))

print("Number of documents have LocalAuthorityName as Dover", len(results))
# Out:
# Number of documents have LocalAuthorityName as Dover 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': "Dover"})

# %%
# Check if any remaining documents include Dover
dover_query = {'$match': {'LocalAuthorityName': "Dover"}}

dover = [dover_query]

results = list(establishments.aggregate(dover))

print("Number of documents have LocalAuthorityName as Dover", len(results))
# Out:
# Number of documents have LocalAuthorityName as Dover 0

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bdac304823ed3bc60a7206'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude

establishments.update_many({}, [ {'$set':{ "geocode.longitude" : {'$toDecimal': "$geocode.longitude"}}} ])

# %%
# Change the data type from String to Decimal for latitude

establishments.update_many({}, [ {'$set':{ "geocode.latitude" : {'$toDecimal': "$geocode.latitude"}}} ])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [ {'$set':{"RatingValue": {"$toInt": "$RatingValue"}}} ])

# %%
# Check that the coordinates and rating value are now numbers
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bdac304823ed3bc60a7206'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
